# %% [markdown]
# ## 1. Loading csv files from data folder

# %%
import pandas as pd
from pathlib import Path

data_dir = Path("../data/raw")  # relative to the notebook folder

customers = pd.read_csv(data_dir / "customers.csv")
order_items = pd.read_csv(data_dir / "order_items.csv")
orders = pd.read_csv(data_dir / "orders.csv")
products = pd.read_csv(data_dir / "products.csv")

# %% [markdown]
# There are four different files in the dataset: customers.csv, order_items.csv, orders.csv, and products.csv

# %%
customers.head()
# Out:
#    customer_id  gender first_name last_name       full_name   age       city  \
# 0            0  Female       Riya  Malhotra   Riya Malhotra  19.0       Pune
# 1            1    Male     Suresh     Gupta    Suresh Gupta  27.0  Hyderabad
# 2            2    Male       Amit     Reddy      Amit Reddy  37.0  Bangalore
# 3            3    Male      Rohit  Malhotra  Rohit Malhotra  59.0       Pune
# 4            4  Female       Neha      Iyer       Neha Iyer  56.0      Delhi
#
#   signup_date
# 0  2024-09-30
# 1  2025-11-13
# 2  2023-04-18
# 3  2024-12-28
# 4  2024-08-19

# %%
order_items.head()
# Out:
#   order_id  product_id  quantity  unit_price  discount  net_amount
# 0    Byk-0        6514         3     3614.06    275.99    10566.19
# 1    Byk-0        2222         4     4539.08   1090.19    17066.13
# 2    Byk-0       40137         4       85.64     12.91      329.65
# 3    Byk-1       48440         3     1384.96    317.69     3837.19
# 4    Byk-1       52122         1     3002.00    108.78     2893.22

# %%
orders.head()
# Out:
#   order_id  customer_id  order_date                  order_ts     city state  \
# 0    Byk-0       651198  2025-11-20  2025-11-20T16:38:56.000Z    Delhi    DL
# 1    Byk-1       192749  2025-12-07  2025-12-07T12:24:38.000Z     Pune    MH
# 2    Byk-2       217349  2025-04-10  2025-04-10T23:41:58.000Z  Chennai    TN
# 3    Byk-3       405295  2025-10-31  2025-10-31T13:24:18.000Z    Delhi    DL
# 4    Byk-4        93506  2025-06-21  2025-06-21T19:14:54.000Z  Kolkata    WB
#
#   payment_method order_status  total_amount
# 0         Wallet    Cancelled       1755.48
# 1     Debit Card    Delivered       6055.63
# 2    Credit Card    Delivered       1413.51
# 3            COD    Delivered       3157.44
# 4     Debit Card    Delivered       4219.23

# %%
products.head()
# Out:
#    product_id             brand       category sub_category      mrp
# 0           0    Nykaa Naturals      Fragrance      Compact  4833.00
# 1           1             Lakme  Personal Care        Serum   710.60
# 2           2    Nykaa Naturals  Personal Care     Eyeliner  3217.86
# 3           3  WOW Skin Science       Skincare    Sanitizer  4979.63
# 4           4             Lakme       Haircare         Soap   347.29

# %% [markdown]
# ## 2. Counting of **MISSING VALUE** for each file

# %%
for name, df in [
    ("customers", customers),
    ("order_items", order_items),
    ("orders", orders),
    ("products", products),
]:
    print(f"{name} missing values:")
    print(df.isna().sum())
    print()
# Out:
# customers missing values:
# customer_id        0
# gender         20059
# first_name     10045
# last_name       9978
# full_name      19933
# age            19960
# city           19776
# signup_date        0
# dtype: int64
#
# order_items missing values:
# order_id          0
# product_id        0
# quantity          0
# unit_price        0
# discount      29984
# net_amount        0
# dtype: int64
#
# orders missing values:
# order_id              0
# customer_id           0
# order_date            0
# order_ts              0
# city              19844
# state             19993
# payment_method    29888
# order_status       9934
# total_amount          0
# dtype: int64
#
# products missing values:
# product_id         0
# brand           5135
# category        5106
# sub_category    5066
# mrp             2946
# dtype: int64

# %% [markdown]
# ### 2.1. **customers** table

# %% [markdown]
# #### 2.1.1. Handling the missing values in **customers** table

# %%
# fill full_name when missing (from first_name + last_name)
mask = customers["full_name"].isna()
customers.loc[mask, "full_name"] = (
    customers.loc[mask, "first_name"].fillna("") + " " + customers.loc[mask, "last_name"].fillna("")
).str.strip()
customers.loc[customers["full_name"] == "", "full_name"] = pd.NA

# fill missing gender as "U"
customers["gender"] = customers["gender"].fillna("U")

# if age has NaNs, use pandas nullable integer dtype
customers["age"] = customers["age"].astype("Int64")

customers.isna().sum()
# Out:
# customer_id        0
# gender             0
# first_name     10045
# last_name       9978
# full_name         90
# age            19960
# city           19776
# signup_date        0
# dtype: int64

# %%
mask = customers["first_name"].isna() & customers["last_name"].isna()

customers.loc[mask, "first_name"] = "unknown"
customers.loc[mask, "last_name"] = "unknown"
customers.loc[mask, "full_name"] = "Unknown"

# if you also want to fill any remaining "full_name" gaps globally
customers["full_name"] = customers["full_name"].fillna("Unknown")

customers[mask]
# Out:
#         customer_id  gender first_name last_name full_name  age       city  \
# 2887           2887  Female    unknown   unknown   Unknown   22    Chennai
# 6337           6337    Male    unknown   unknown   Unknown   40      Delhi
# 9013           9013    Male    unknown   unknown   Unknown   31  Hyderabad
# 42842         42842  Female    unknown   unknown   Unknown   20       Pune
# 55723         55723  Female    unknown   unknown   Unknown   33    Kolkata
# ...             ...     ...        ...       ...       ...  ...        ...
# 950487       950487  Female    unknown   unknown   Unknown   27    Chennai
# 951124       951124  Female    unknown   unknown   Unknown   53  Bangalore
# 958045       958045    Male    unknown   unknown   Unknown   45        NaN
# 963014       963014    Male    unknown   unknown   Unknown   35  Bangalore
# 971313       971313  Female    unknown   unknown   Unknown   35  Hyderabad
#
#        signup_date
# 2887    2024-06-17
# 6337    2025-11-12
# 9013    2024-11-17
# 42842   2023-10-24
# 55723   2022-08-18
# ...            ...
# 950487  2025-12-23
# 951124  2023-09-10
# 958045  2025-02-20
# 963014  2023-09-06
# 971313  2022-02-25
#
# [90 rows x 8 columns]

# %% [markdown]
# Map cities between **customers** and **orders** by *customer_id*

# %%
# map cities between customers and orders by customer_id
cust_city = customers.set_index("customer_id")["city"]

# fill missing in orders from customers
mask = orders["city"].isna() & orders["customer_id"].notna()
orders.loc[mask, "city"] = orders.loc[mask, "customer_id"].map(cust_city)

# infer customer city from orders when missing in customers
orders_city_by_customer = (
    orders[orders["city"].notna()]
    .groupby("customer_id")["city"]
    .agg(lambda x: x.mode().iat[0] if not x.mode().empty else None)
)
mask = customers["city"].isna() & customers["customer_id"].notna()
customers.loc[mask, "city"] = customers.loc[mask, "customer_id"].map(orders_city_by_customer)

# %%
# final fallback
customers["city"] = customers["city"].fillna("unknown")
customers["first_name"] = customers["first_name"].fillna("unknown")
customers["last_name"] = customers["last_name"].fillna("unknown")

# %% [markdown]
# #### 2.1.2. Find and Drop the **duplicates** in customer table

# %%
# find duplicates by customer_id (or by all columns)
dups_by_id = customers[customers.duplicated(subset=["customer_id"], keep=False)]
dups_full = customers[customers.duplicated(keep=False)]

print("duplicates by customer_id:", len(dups_by_id))
print("full-row duplicates:", len(dups_full))

# inspect a few
dups_by_id.head()
dups_full.head()

# drop duplicates (keep first occurrence)
customers = customers.drop_duplicates(subset=["customer_id"], keep="first").reset_index(drop=True)

# (optional) if you want to drop only exact full-row duplicates:
# customers = customers.drop_duplicates(keep="first").reset_index(drop=True)
# Out:
# duplicates by customer_id: 0
# full-row duplicates: 0

# %%
customers.isna().sum()
# Out:
# customer_id        0
# gender             0
# first_name         0
# last_name          0
# full_name          0
# age            19960
# city               0
# signup_date        0
# dtype: int64

# %% [markdown]
# ### 2.2. **order_items** table

# %% [markdown]
# ### 2.2.1. Handling the missing values in **order_items** table

# %%
# fill missing discount = net_amount - unit_price * quantity
mask = order_items["discount"].isna()
order_items.loc[mask, "discount"] = abs(
    order_items.loc[mask, "net_amount"]
    - order_items.loc[mask, "unit_price"] * order_items.loc[mask, "quantity"]
)

order_items.isna().sum()
# Out:
# order_id      0
# product_id    0
# quantity      0
# unit_price    0
# discount      0
# net_amount    0
# dtype: int64

# %%
# Remove any commas, spaces, or percent signs from numeric columns
for col in ["unit_price", "discount", "net_amount"]:
    order_items[col] = (
        order_items[col]
        .astype(str)                     # Ensure string first
        .str.replace(",", "", regex=False)  # Remove commas
        .str.replace("%", "", regex=False)  # Remove percent
        .str.strip()                     # Remove leading/trailing spaces
    )
    # Convert to float, invalid values become NaN
    order_items[col] = pd.to_numeric(order_items[col], errors="coerce").round(2)

# Convert integer columns safely
order_items["quantity"] = pd.to_numeric(order_items["quantity"], errors="coerce").astype("Int64")
order_items["product_id"] = pd.to_numeric(order_items["product_id"], errors="coerce").astype("Int64")

# Convert order_id to string
order_items["order_id"] = order_items["order_id"].astype(str)

# Optional: fill NaNs with 0
order_items[["discount", "net_amount", "unit_price"]] = order_items[["discount", "net_amount", "unit_price"]].fillna(0)

# %%
print(order_items.dtypes)
# Out:
# order_id       object
# product_id      Int64
# quantity        Int64
# unit_price    float64
# discount      float64
# net_amount    float64
# dtype: object

# %% [markdown]
# ### 2.2.2. Handling the duplicates in **order_items** table

# %%
# find duplicates in order_items (by key columns or full row)
dups_by_key = order_items[order_items.duplicated(subset=["order_id", "product_id"], keep=False)]
dups_full = order_items[order_items.duplicated(keep=False)]

print("duplicates by (order_id, product_id):", len(dups_by_key))
print("full-row duplicates:", len(dups_full))

# inspect a few
dups_by_key.head()
dups_full.head()

# drop duplicates (keep first occurrence)
order_items = order_items.drop_duplicates(subset=["order_id", "product_id"], keep="first").reset_index(drop=True)

# (or, if you want to drop only exact full-row duplicates:)
# order_items = order_items.drop_duplicates(keep="first").reset_index(drop=True)
# Out:
# duplicates by (order_id, product_id): 0
# full-row duplicates: 0

# %% [markdown]
# ### 2.3 **orders** table

# %% [markdown]
# ### 2.3.1. Handling the missing values in **orders** table

# %%
orders.isna().sum()
# Out:
# order_id              0
# customer_id           0
# order_date            0
# order_ts              0
# city                382
# state             19993
# payment_method    29888
# order_status       9934
# total_amount          0
# dtype: int64

# %%
# unique cities per state in orders
cities_by_state = (
    orders[["state", "city"]]
    .drop_duplicates()
    .sort_values(["state", "city"])
)

cities_by_state.head(50)  # or `cities_by_state` to view all
# Out:
#        state       city
# 0         DL      Delhi
# 17        KA  Bangalore
# 6         MH     Mumbai
# 1         MH       Pune
# 2         TN    Chennai
# 9         TS  Hyderabad
# 48        WB  Bangalore
# 45        WB    Chennai
# 49        WB      Delhi
# 247       WB  Hyderabad
# 4         WB    Kolkata
# 457       WB     Mumbai
# 134       WB       Pune
# 1968      WB        NaN
# 209      NaN  Bangalore
# 303      NaN    Chennai
# 133      NaN      Delhi
# 968      NaN  Hyderabad
# 164      NaN    Kolkata
# 413      NaN     Mumbai
# 225      NaN       Pune
# 154807   NaN        NaN

# %%
# build fill maps from existing (state, city) pairs
valid = orders.dropna(subset=["state", "city"])

# most common state for each city
city_to_state = valid.groupby("city")["state"].agg(lambda s: s.mode().iat[0] if not s.mode().empty else None)

# most common city for each state
state_to_city = valid.groupby("state")["city"].agg(lambda s: s.mode().iat[0] if not s.mode().empty else None)

# fill when one is missing
mask_state_missing = orders["state"].isna() & orders["city"].notna()
orders.loc[mask_state_missing, "state"] = orders.loc[mask_state_missing, "city"].map(city_to_state)

mask_city_missing = orders["city"].isna() & orders["state"].notna()
orders.loc[mask_city_missing, "city"] = orders.loc[mask_city_missing, "state"].map(state_to_city)


orders.isna().sum()
# Out:
# order_id              0
# customer_id           0
# order_date            0
# order_ts              0
# city                  9
# state                 9
# payment_method    29888
# order_status       9934
# total_amount          0
# dtype: int64

# %%
# unique cities per state in orders
cities_by_state = (
    orders[["state", "city"]]
    .drop_duplicates()
    .sort_values(["state", "city"])
)

cities_by_state.head(50)  # or `cities_by_state` to view all
# Out:
#        state       city
# 0         DL      Delhi
# 17        KA  Bangalore
# 6         MH     Mumbai
# 1         MH       Pune
# 2         TN    Chennai
# 9         TS  Hyderabad
# 48        WB  Bangalore
# 45        WB    Chennai
# 49        WB      Delhi
# 247       WB  Hyderabad
# 4         WB    Kolkata
# 457       WB     Mumbai
# 134       WB       Pune
# 154807   NaN        NaN

# %%
# if payment_method is missing, mark unknown
mask_both_missing = orders["payment_method"].isna()
orders.loc[mask_both_missing, ["payment_method"]] = "Other"

# %% [markdown]
# if both "state", "city" are missing, mark unknown

# %%
mask_both_missing = orders["state"].isna() & orders["city"].isna()
orders.loc[mask_both_missing, ["state", "city"]] = "unknown"

# %%
# if order_status is missing, mark Nonupdated
mask_both_missing = orders["order_status"].isna()
orders.loc[mask_both_missing, ["order_status"]] = "Nonupdated"

orders.isna().sum()
# Out:
# order_id          0
# customer_id       0
# order_date        0
# order_ts          0
# city              0
# state             0
# payment_method    0
# order_status      0
# total_amount      0
# dtype: int64

# %%
orders.head()
# Out:
#   order_id  customer_id  order_date                  order_ts     city state  \
# 0    Byk-0       651198  2025-11-20  2025-11-20T16:38:56.000Z    Delhi    DL
# 1    Byk-1       192749  2025-12-07  2025-12-07T12:24:38.000Z     Pune    MH
# 2    Byk-2       217349  2025-04-10  2025-04-10T23:41:58.000Z  Chennai    TN
# 3    Byk-3       405295  2025-10-31  2025-10-31T13:24:18.000Z    Delhi    DL
# 4    Byk-4        93506  2025-06-21  2025-06-21T19:14:54.000Z  Kolkata    WB
#
#   payment_method order_status  total_amount
# 0         Wallet    Cancelled       1755.48
# 1     Debit Card    Delivered       6055.63
# 2    Credit Card    Delivered       1413.51
# 3            COD    Delivered       3157.44
# 4     Debit Card    Delivered       4219.23

# %% [markdown]
# * Convert *order_ts* to datetime and format neatly

# %%
orders['order_ts'] = pd.to_datetime(orders['order_ts']).dt.strftime('%Y-%m-%d %H:%M')

print("Converted order_ts sample:")
print(orders[['order_id', 'order_date', 'order_ts']].head())
# Out:
# Converted order_ts sample:
#   order_id  order_date          order_ts
# 0    Byk-0  2025-11-20  2025-11-20 16:38
# 1    Byk-1  2025-12-07  2025-12-07 12:24
# 2    Byk-2  2025-04-10  2025-04-10 23:41
# 3    Byk-3  2025-10-31  2025-10-31 13:24
# 4    Byk-4  2025-06-21  2025-06-21 19:14

# %% [markdown]
# ### 2.3.2. Handling the duplicates in **orders** table

# %%
# find duplicates by order_id (or by all columns)
dups_by_id = orders[orders.duplicated(subset=["order_id"], keep=False)]
dups_full = orders[orders.duplicated(keep=False)]

print("duplicates by order_id:", len(dups_by_id))
print("full-row duplicates:", len(dups_full))

# inspect a few
dups_by_id.head()
dups_full.head()

# drop duplicates (keep first occurrence)
orders = orders.drop_duplicates(subset=["order_id"], keep="first").reset_index(drop=True)

# (or, if you want to drop only exact full-row duplicates:)
# orders = orders.drop_duplicates(keep="first").reset_index(drop=True)
# Out:
# duplicates by order_id: 0
# full-row duplicates: 0

# %% [markdown]
# ### 2.4. **products** table

# %%
products.head()
# Out:
#    product_id             brand       category sub_category      mrp
# 0           0    Nykaa Naturals      Fragrance      Compact  4833.00
# 1           1             Lakme  Personal Care        Serum   710.60
# 2           2    Nykaa Naturals  Personal Care     Eyeliner  3217.86
# 3           3  WOW Skin Science       Skincare    Sanitizer  4979.63
# 4           4             Lakme       Haircare         Soap   347.29

# %%
products.isna().sum()
# Out:
# product_id         0
# brand           5135
# category        5106
# sub_category    5066
# mrp             2946
# dtype: int64

# %%
# Standardize product categories based on subcategories
sub_to_standard_cat = {
    'Compact': 'Makeup',
    'Serum': 'Skincare',
    'Eyeliner': 'Makeup',
    'Sanitizer': 'Personal Care',
    'Soap': 'Personal Care',
    'Face Wash': 'Skincare',
    'Sunscreen': 'Skincare',
    'Oil': 'Skincare',
    'Perfume': 'Fragrance',
    'Handwash': 'Personal Care',
    'Hair Mask': 'Haircare',
    'Deodorant': 'Fragrance',
    'Mask': 'Skincare',
    'Mascara': 'Makeup',
    'Foundation': 'Makeup',
    'Moisturizer': 'Skincare',
    'Conditioner': 'Haircare',
    'Lipstick': 'Makeup',
    'Body Mist': 'Fragrance',
    'Shampoo': 'Haircare',
    'Body Lotion': 'Personal Care',
    'other': 'Other'
}

# Apply the mapping
products['category'] = products['sub_category'].map(sub_to_standard_cat).fillna('Other')

print("Updated unique categories:", products['category'].unique())
print("\nSample products:")
print(products[['product_id', 'brand', 'category', 'sub_category']].head(10))
# Out:
# Updated unique categories: ['Makeup' 'Skincare' 'Personal Care' 'Fragrance' 'Haircare' 'Other']
#
# Sample products:
#    product_id             brand       category sub_category
# 0           0    Nykaa Naturals         Makeup      Compact
# 1           1             Lakme       Skincare        Serum
# 2           2    Nykaa Naturals         Makeup     Eyeliner
# 3           3  WOW Skin Science  Personal Care    Sanitizer
# 4           4             Lakme  Personal Care         Soap
# 5           5           L'Oreal       Skincare    Face Wash
# 6           6          Biotique       Skincare    Sunscreen
# 7           7    Nykaa Naturals       Skincare          Oil
# 8           8          Biotique  Personal Care         Soap
# 9           9          Himalaya      Fragrance      Perfume

# %%
# Standardize subcategories to title case
products['sub_category'] = products['sub_category'].str.title()

print("Standardized unique subcategories:", products['sub_category'].unique())
print("\nSample products with standardized subcategories:")
print(products[['product_id', 'brand', 'category', 'sub_category']].head(10))
# Out:
# Standardized unique subcategories: ['Compact' 'Serum' 'Eyeliner' 'Sanitizer' 'Soap' 'Face Wash' 'Sunscreen'
#  'Oil' 'Perfume' 'Handwash' 'Hair Mask' 'Deodorant' 'Mask' 'Mascara'
#  'Foundation' 'Moisturizer' 'Conditioner' 'Lipstick' 'Body Mist' nan
#  'Shampoo' 'Body Lotion']
#
# Sample products with standardized subcategories:
#    product_id             brand       category sub_category
# 0           0    Nykaa Naturals         Makeup      Compact
# 1           1             Lakme       Skincare        Serum
# 2           2    Nykaa Naturals         Makeup     Eyeliner
# 3           3  WOW Skin Science  Personal Care    Sanitizer
# 4           4             Lakme  Personal Care         Soap
# 5           5           L'Oreal       Skincare    Face Wash
# 6           6          Biotique       Skincare    Sunscreen
# 7           7    Nykaa Naturals       Skincare          Oil
# 8           8          Biotique  Personal Care         Soap
# 9           9          Himalaya      Fragrance      Perfume

# %%
# unique sub_category per category in products
subcategory_by_category = (
    products[["category", "sub_category"]]
    .drop_duplicates()
    .sort_values(["category", "sub_category"])
)

subcategory_by_category.head(10)
# Out:
#      category sub_category
# 33  Fragrance    Body Mist
# 15  Fragrance    Deodorant
# 9   Fragrance      Perfume
# 28   Haircare  Conditioner
# 12   Haircare    Hair Mask
# 57   Haircare      Shampoo
# 0      Makeup      Compact
# 2      Makeup     Eyeliner
# 25     Makeup   Foundation
# 29     Makeup     Lipstick

# %%
# build map from sub_category → most common category
valid = products.dropna(subset=["sub_category", "category"])
sub_to_cat = valid.groupby("sub_category")["category"].agg(
    lambda s: s.mode().iat[0] if not s.mode().empty else None
)

# fill missing category when sub_category is present
mask = products["category"].isna() & products["sub_category"].notna()
products.loc[mask, "category"] = products.loc[mask, "sub_category"].map(sub_to_cat)

products.isna().sum()
# Out:
# product_id         0
# brand           5135
# category           0
# sub_category    5066
# mrp             2946
# dtype: int64

# %%
# fill missing sub_category using (brand, category) → most common sub_category
valid = products.dropna(subset=["brand", "category", "sub_category"])
brand_cat_to_sub = (
    valid.groupby(["brand", "category"])["sub_category"]
    .agg(lambda s: s.mode().iat[0] if not s.mode().empty else None)
)

mask = products["sub_category"].isna() & products["brand"].notna() & products["category"].notna()
products.loc[mask, "sub_category"] = (
    products.loc[mask, ["brand", "category"]]
    .apply(tuple, axis=1)
    .map(brand_cat_to_sub)
)

# fill missing category using (brand, sub_category) → most common category
valid = products.dropna(subset=["brand", "sub_category", "category"])
brand_sub_to_cat = (
    valid.groupby(["brand", "sub_category"])["category"]
    .agg(lambda s: s.mode().iat[0] if not s.mode().empty else None)
)

mask = products["category"].isna() & products["brand"].notna() & products["sub_category"].notna()
products.loc[mask, "category"] = (
    products.loc[mask, ["brand", "sub_category"]]
    .apply(tuple, axis=1)
    .map(brand_sub_to_cat)
)

products.isna().sum()
# Out:
# product_id         0
# brand           5135
# category           0
# sub_category    5066
# mrp             2946
# dtype: int64

# %%
# fill remaining missing values in product taxonomy columns
products[["brand", "category", "sub_category"]] = products[
    ["brand", "category", "sub_category"]
].fillna("other")

products.isna().sum()
# Out:
# product_id         0
# brand              0
# category           0
# sub_category       0
# mrp             2946
# dtype: int64

# %% [markdown]
# ## 3. Counting of **MISSING VALUE** for each file after cleaning

# %%
for name, df in [
    ("customers", customers),
    ("order_items", order_items),
    ("orders", orders),
    ("products", products),
]:
    print(f"{name} missing values:")
    print(df.isna().sum())
    print()
# Out:
# customers missing values:
# customer_id        0
# gender             0
# first_name         0
# last_name          0
# full_name          0
# age            19960
# city               0
# signup_date        0
# dtype: int64
#
# order_items missing values:
# order_id      0
# product_id    0
# quantity      0
# unit_price    0
# discount      0
# net_amount    0
# dtype: int64
#
# orders missing values:
# order_id          0
# customer_id       0
# order_date        0
# order_ts          0
# city              0
# state             0
# payment_method    0
# order_status      0
# total_amount      0
# dtype: int64
#
# products missing values:
# product_id         0
# brand              0
# category           0
# sub_category       0
# mrp             2946
# dtype: int64

# %% [markdown]
# Now, let's see how the columns still exist missing values perform after we cleaned the data.
# Specifically, we have the column *age* in **customer** table and *mrp* in **products** table

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 4) distributions for key numeric columns (histograms)
num_cols = {
    "customers": ["age"],
    "products": ["mrp"],  
}
for name, cols in num_cols.items():
    df = locals()[name]
    for c in cols:
        if c in df:
            plt.figure(figsize=(5, 3))
            sns.histplot(df[c].dropna(), kde=True, bins=30)
            plt.title(f"{name} {c} distribution")
            plt.tight_layout()
            plt.show()

# %% [markdown]
# Handling the missing value in *age* column and *mrp* column in **customer** table and **product** table respectively.

# %%
import pandas as pd
import numpy as np

# Example: customers = pd.read_csv("customers.csv")

# --- Step 0: define age range ---
min_age = int(customers['age'].min(skipna=True))
max_age = int(customers['age'].max(skipna=True))

# create 30 bins (same idea as MRP)
bins = np.linspace(min_age, max_age, 31)

labels = [f"{int(bins[i])}-{int(bins[i+1])}" for i in range(len(bins)-1)]

# assign bins
customers['age_range'] = pd.cut(
    customers['age'],
    bins=bins,
    labels=labels,
    include_lowest=True
)

# --- Step 1: current distribution ---
bin_counts = customers['age_range'].value_counts().sort_index()

total_rows = len(customers)
missing_count = customers['age'].isna().sum()

target_per_bin = total_rows // len(labels)

# --- Step 2: needed per bin ---
needed_per_bin = target_per_bin - bin_counts
needed_per_bin = needed_per_bin.clip(lower=0)

# --- Step 3: generate values ---
filled_values = []

for i, label in enumerate(labels):
    n_needed = int(needed_per_bin.iloc[i])
    if n_needed > 0:
        low = bins[i]
        high = bins[i + 1]
        
        samples = np.random.uniform(low, high, n_needed)
        filled_values.extend(samples)

# handle leftover
remaining = missing_count - len(filled_values)
if remaining > 0:
    extra_samples = np.random.uniform(min_age, max_age, remaining)
    filled_values.extend(extra_samples)

np.random.shuffle(filled_values)

# --- Step 4: assign to missing ---
customers['age'] = customers['age'].astype(float)
customers.loc[customers['age'].isna(), 'age'] = filled_values[:missing_count]

# optional: round ages to integers
customers['age'] = customers['age'].round().astype(int)

# --- Step 5: recompute bins ---
customers['age_range'] = pd.cut(
    customers['age'],
    bins=bins,
    labels=labels,
    include_lowest=True
)

# %%
import numpy as np

# Define bins
bins = np.linspace(0, 5100, 31)  # 30 ranges → 31 edges

# Create labels (optional, for readability)
labels = [f"{int(bins[i])}-{int(bins[i+1])}" for i in range(len(bins)-1)]

# Create range column
products['mrp_range'] = pd.cut(products['mrp'], bins=bins, labels=labels, include_lowest=True)

# %%
# --- Step 1: count current distribution ---
bin_counts = products['mrp_range'].value_counts().sort_index()

# total rows and missing count
total_rows = len(products)
missing_count = products['mrp'].isna().sum()

# target per bin (equal distribution)
target_per_bin = total_rows // len(labels)

# --- Step 2: calculate how many values to add per bin ---
needed_per_bin = target_per_bin - bin_counts
needed_per_bin = needed_per_bin.clip(lower=0)  # no negatives

# --- Step 3: generate values for missing MRP ---
filled_values = []

for i, label in enumerate(labels):
    n_needed = int(needed_per_bin.iloc[i])
    if n_needed > 0:
        low = bins[i]
        high = bins[i + 1]
        
        # sample uniformly within the bin
        samples = np.random.uniform(low, high, n_needed)
        filled_values.extend(samples)

# If still missing due to rounding, fill remaining randomly
remaining = missing_count - len(filled_values)
if remaining > 0:
    extra_samples = np.random.uniform(0, 5100, remaining)
    filled_values.extend(extra_samples)

# shuffle to avoid order bias
np.random.shuffle(filled_values)

# --- Step 4: assign to missing rows ---
products.loc[products['mrp'].isna(), 'mrp'] = filled_values[:missing_count]

# --- Step 5: recompute bins after filling ---
products['mrp_range'] = pd.cut(products['mrp'], bins=bins, labels=labels, include_lowest=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 4) distributions for key numeric columns (histograms)
num_cols = {
    "customers": ["age", "age_range"],
    "products": ["mrp", "mrp_range"],  
}
for name, cols in num_cols.items():
    df = locals()[name]
    for c in cols:
        if c in df:
            plt.figure(figsize=(5, 3))
            sns.histplot(df[c].dropna(), kde=True, bins=30)
            plt.xticks(rotation=90)
            plt.title(f"{name} {c} distribution")
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ### Drop the extra columns: mrp_range and age_range

# %%
products.drop(columns=["mrp_range"], inplace=True)
customers.drop(columns=["age_range"], inplace=True)

# %%
for name, df in [
    ("customers", customers),
    ("order_items", order_items),
    ("orders", orders),
    ("products", products),
]:
    print(f"{name} missing values:")
    print(df.isna().sum())
    print()
# Out:
# customers missing values:
# customer_id    0
# gender         0
# first_name     0
# last_name      0
# full_name      0
# age            0
# city           0
# signup_date    0
# dtype: int64
#
# order_items missing values:
# order_id      0
# product_id    0
# quantity      0
# unit_price    0
# discount      0
# net_amount    0
# dtype: int64
#
# orders missing values:
# order_id          0
# customer_id       0
# order_date        0
# order_ts          0
# city              0
# state             0
# payment_method    0
# order_status      0
# total_amount      0
# dtype: int64
#
# products missing values:
# product_id      0
# brand           0
# category        0
# sub_category    0
# mrp             0
# dtype: int64

# %% [markdown]
# **All done!**

# %% [markdown]
# ### Convert data to numeric if needed

# %%
import pandas as pd
import csv
from pathlib import Path
import subprocess

# ============================================================================
# 1. Paths and directories
# ============================================================================
CLEAN_DIR = Path("../data/cleaned")
CLEAN_DIR.mkdir(parents=True, exist_ok=True)

# %%
# ============================================================================
# 3. Mapping dictionaries
# ============================================================================
city_map_lower = {
    'pune': 1, 'hyderabad': 2, 'bangalore': 3,
    'delhi': 4, 'mumbai': 5, 'kolkata': 6,
    'chennai': 7, 'unknown': 0
}
state_map_lower = {
    'DL': 1, 'MH': 2, 'TN': 3, 'WB': 4, 'TS': 5, 'KA': 6, 'unknown': 0
}
payment_method_map = {
    'Wallet': 1, 'Debit Card': 2, 'Credit Card': 3,
    'COD': 4, 'UPI': 5, 'Other': 6
}
order_status_map = {
    'Cancelled': 1, 'Delivered': 2, 'Returned': 3, 'Nonupdated': 4
}
brand_map = {
    'nykaa naturals': 1, 'lakme': 2, 'wow skin science': 3, "l'oreal": 4,
    'biotique': 5, 'himalaya': 6, 'other': 7, "pond's": 8,
    'the body shop': 9, 'forest essentials': 10, 'mamaearth': 11,
    'nivea': 12, 'maybelline': 13
}
category_map = {
    'makeup': 1, 'skincare': 2, 'personal care': 3,
    'fragrance': 4, 'haircare': 5, 'other': 6
}
sub_category_map = {
    'compact': 1, 'serum': 2, 'eyeliner': 3, 'sanitizer': 4,
    'soap': 5, 'face wash': 6, 'sunscreen': 7, 'oil': 8,
    'perfume': 9, 'handwash': 10, 'hair mask': 11, 'deodorant': 12,
    'mask': 13, 'mascara': 14, 'foundation': 15, 'moisturizer': 16,
    'conditioner': 17, 'lipstick': 18, 'body mist': 19, 'other': 20,
    'shampoo': 21, 'body lotion': 22
}
gender_map = {'male': 1, 'female': 0, 'u': 2}

# Helper function to apply mapping and force int (fill NaN with 0)
def map_to_int(series, mapping, default=0):
    return series.astype(str).str.lower().map(mapping).fillna(default).astype(int)

# %%
# ============================================================================
# 4. Clean customers
# ============================================================================
# Create full_name
customers['full_name'] = customers['first_name'].astype(str) + ' ' + customers['last_name'].astype(str)
customers.drop(columns=['first_name', 'last_name'], inplace=True)

# Map gender and city (robust)
customers['gender'] = map_to_int(customers['gender'], gender_map, default=2)   # unknown = 2
customers['city'] = map_to_int(customers['city'], city_map_lower)

# Reorder columns
customers = customers[['customer_id', 'gender', 'full_name', 'age', 'city', 'signup_date']]

# %%
# ============================================================================
# 5. Clean order_items (unchanged)
# ============================================================================
order_items['order_id'] = order_items['order_id'].astype(str).str.replace('Byk-', '', regex=False).astype(int)

# ============================================================================
# 6. Clean orders
# ============================================================================
# Save original city/state names
orders['city_name'] = orders['city'].astype(str)
orders['state_name'] = orders['state'].astype(str)

# Convert order_id
orders['order_id'] = orders['order_id'].astype(str).str.replace('Byk-', '', regex=False).astype(int)

# Map city and state (using saved strings)
orders['city'] = map_to_int(orders['city_name'], city_map_lower)
orders['state'] = orders['state_name'].str.upper().map(state_map_lower).fillna(0).astype(int)

# Convert order_ts: let pandas infer format (supports both with/without seconds)
orders['order_ts'] = pd.to_datetime(orders['order_ts'])  # no format string
orders['order_ts'] = orders['order_ts'].dt.strftime('%H:%M:%S')   # e.g., '16:38:00'

# Map payment and status (strings, so .map works)
orders['payment_method'] = orders['payment_method'].map(payment_method_map).fillna(0).astype(int)
orders['order_status'] = orders['order_status'].map(order_status_map).fillna(0).astype(int)

# ===== Build location_df BEFORE dropping names =====
location_df = (
    orders[['city', 'state']]
    .drop_duplicates()                         # remove exact duplicate pairs
    .drop_duplicates(subset='city', keep='first')  # keep one state per city (first occurrence)
    .sort_values('city')
    .rename(columns={'city': 'city_code', 'state': 'state_code'})
)

# ----------------------------------------------------------------------
# Reverse mappings (code -> name)
# ----------------------------------------------------------------------
reverse_city = {v: k for k, v in city_map_lower.items()}    # {1:'pune', 2:'hyderabad', ...}
reverse_state = {v: k for k, v in state_map_lower.items()}  # {1:'DL', 2:'MH', ...}

# Add city_name and state_name using reverse mappings
location_df['city_name'] = location_df['city_code'].map(reverse_city).fillna('unknown')
location_df['state_name'] = location_df['state_code'].map(reverse_state).fillna('unknown')

# Reorder columns for location.csv
location_df = location_df[['city_code', 'city_name', 'state_code', 'state_name']]

# ----------------------------------------------------------------------
# Reorder orders to match SQL staging table
# ----------------------------------------------------------------------
orders = orders[['order_id', 'customer_id', 'order_date', 'city', 'state',
                 'payment_method', 'order_status', 'total_amount', 'order_ts']]

# Save location.csv
location_df.to_csv(CLEAN_DIR / 'location.csv', index=False)

# ============================================================================
# 7. Clean products
# ============================================================================
products['brand'] = map_to_int(products['brand'], brand_map)
products['category'] = map_to_int(products['category'], category_map)
products['sub_category'] = map_to_int(products['sub_category'], sub_category_map)

# Reorder to match products_table
products = products[['product_id', 'brand', 'category', 'sub_category', 'mrp']]

# %%
order_temp=orders[['city', 'state']].drop_duplicates()
order_temp.head()
# Out:
#    city  state
# 0     4      1
# 1     1      2
# 2     7      3
# 4     6      4
# 6     5      2

# %%
# ============================================================================
# 9. Save mapping tables (payment, status, brand, category, sub_category)
# ============================================================================
mappings_to_save = [
    (payment_method_map, 'payment_method.csv', 'payment_method'),
    (order_status_map, 'order_status.csv', 'status_name'),
    (brand_map, 'brand.csv', 'brand_name'),
    (category_map, 'category.csv', 'category_name'),
    (sub_category_map, 'sub_category.csv', 'sub_category_name'),
]

for mapping, filename, name_col in mappings_to_save:
    filepath = CLEAN_DIR / filename
    with open(filepath, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow([name_col, 'code'])
        for name, code in sorted(mapping.items(), key=lambda x: x[1]):
            writer.writerow([name, code])
    print(f"Saved {filepath}")

# Save location.csv (integers already)
location_df.to_csv(CLEAN_DIR / 'location.csv', index=False)
print(f"Saved {CLEAN_DIR / 'location.csv'}")

# ============================================================================
# 10. Save cleaned DataFrames
# ============================================================================
customers.to_csv(CLEAN_DIR / 'customers.csv', index=False)
order_items.to_csv(CLEAN_DIR / 'order_items.csv', index=False)
orders.to_csv(CLEAN_DIR / 'orders.csv', index=False)
products.to_csv(CLEAN_DIR / 'products.csv', index=False)
print("All cleaned data saved successfully!")
# Out:
# Saved ../data/cleaned/payment_method.csv
# Saved ../data/cleaned/order_status.csv
# Saved ../data/cleaned/brand.csv
# Saved ../data/cleaned/category.csv
# Saved ../data/cleaned/sub_category.csv
# Saved ../data/cleaned/location.csv
# All cleaned data saved successfully!

# %%
# ============================================================================
# 11. (Optional) Copy to Docker container and fix date columns
# ============================================================================
# (A) Copy files to container
def copy_to_docker(files, container="sql_server_container", dest="/var/opt/mssql/data/"):
    for fname in files:
        src = CLEAN_DIR / fname
        if src.exists():
            result = subprocess.run(
                ["docker", "cp", str(src), f"{container}:{dest}{fname}"],
                capture_output=True, text=True
            )
            if result.returncode == 0:
                print(f"✅ Copied {fname}")
            else:
                print(f"❌ Failed to copy {fname}: {result.stderr}")
        else:
            print(f"⚠️ Local file missing: {src}")

files_to_copy = [
    "customers.csv", "products.csv", "orders.csv", "order_items.csv",
    "location.csv", "payment_method.csv", "order_status.csv",
    "brand.csv", "category.csv", "sub_category.csv"
]
copy_to_docker(files_to_copy)
# Out:
# ✅ Copied customers.csv
# ✅ Copied products.csv
# ✅ Copied orders.csv
# ✅ Copied order_items.csv
# ✅ Copied location.csv
# ✅ Copied payment_method.csv
# ✅ Copied order_status.csv
# ✅ Copied brand.csv
# ✅ Copied category.csv
# ✅ Copied sub_category.csv

# %%
# (B) Change ownership inside container
subprocess.run(
    ["docker", "exec", "sql_server_container", "sh", "-c", "chown mssql:mssql /var/opt/mssql/data/*.csv"],
    capture_output=True
)

# Convert date columns (optional, but ensures proper DATE type)
def convert_date_columns(files_with_dates):
    for fname in files_with_dates:
        filepath = CLEAN_DIR / fname
        if not filepath.exists():
            continue
        df = pd.read_csv(filepath)
        date_cols = [col for col in df.columns if 'date' in col.lower()]
        for col in date_cols:
            df[col] = pd.to_datetime(df[col], errors='coerce')
        df.to_csv(filepath, index=False)
        print(f"✅ Date conversion done for {fname}")

convert_date_columns(["customers.csv", "orders.csv"])

print("\n🎉 All steps completed successfully!")
# Out:
# ✅ Date conversion done for customers.csv
# ✅ Date conversion done for orders.csv
#
# 🎉 All steps completed successfully!

# %%
for name, df in [
    ("customers", customers),
    ("order_items", order_items),
    ("orders", orders),
    ("products", products),
]:
    print(f"{name} missing values:")
    print(df.isna().sum())
    print()
# Out:
# customers missing values:
# customer_id    0
# gender         0
# full_name      0
# age            0
# city           0
# signup_date    0
# dtype: int64
#
# order_items missing values:
# order_id      0
# product_id    0
# quantity      0
# unit_price    0
# discount      0
# net_amount    0
# dtype: int64
#
# orders missing values:
# order_id          0
# customer_id       0
# order_date        0
# city              0
# state             0
# payment_method    0
# order_status      0
# total_amount      0
# order_ts          0
# dtype: int64
#
# products missing values:
# product_id      0
# brand           0
# category        0
# sub_category    0
# mrp             0
# dtype: int64
